# %%
fast_delivery=[20,25,30,28,32,35]
slow_delivery=[45,50,55,60,65,70]
sns.kdeplot(fast_delivery,fill=True,label="Fast")
sns.kdeplot(slow_delivery,fill=True,label="Slow")
plt.legend()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data={
    "Math":[80,85,78,90,88,76,95,89],
    "Science":[82,88,75,92,85,78,96,90],
    "English":[75,80,70,85,83,72,88,86],
    "Hours_Studied":[2,3,2,4,3,2,5,4]
}
df = pd.DataFrame(data)
sns.pairplot(df)
plt.suptitle("Student Performance Pairwise Analysis",y=1.02)
plt.show()
